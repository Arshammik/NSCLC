# %%
suppressPackageStartupMessages(library(data.table))
suppressPackageStartupMessages(library(Seurat))
suppressPackageStartupMessages(library(monocle3))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(tidyverse))
set.seed(42)

# %%
# Files directory

monocole_3_learned_object_RDS_direction <- "/home/arsham79/scratch/nsclc/results/monocole3_cds_objectd_trained.rds"
monocole_3_DEGs_RDS_direction <- "/home/arsham79/scratch/nsclc/results/DEGs_monocole3.rds"

# %%
cds <- readRDS(monocole_3_learned_object_RDS_direction)

# %%
plot_cells(cds, color_cells_by = "partition", label_branch_points=FALSE, label_leaves=FALSE)
# Out:
# plot without title

# %%
plot_cells(cds, color_cells_by = "cell_type", label_groups_by_cluster=FALSE, label_leaves=FALSE, label_branch_points=FALSE, labels_per_group = FALSE)
# Out:
# plot without title

# %%
plot_cells(cds, color_cells_by = "pseudotime", label_groups_by_cluster=FALSE, label_leaves=FALSE, label_branch_points=TRUE)
# Out:
# Cells aren't colored in a way that allows them to be grouped.
# plot without title

# %%
cds$pseudotime_value <- pseudotime(cds)
pseudotime_df <- as.data.frame(colData(cds))

# %%
ggplot(pseudotime_df, aes(x = pseudotime_value, y = reorder(cell_type, pseudotime_value, median), fill = cell_type)) + geom_boxplot() + NoLegend()
# Out:
# plot without title

# %%
degs <- readRDS(monocole_3_DEGs_RDS_direction)
degs <- as.data.table(degs)

# %%
degs <- degs[degs$num_cell_expressed > 9601,]

# %%
degs <- degs[degs$morans_I > 0.100878,]

# %%
genes_to_assess <- degs$gene_short_name

# %%
cds <- preprocess_cds(cds)

# %%
gene_module_df <- find_gene_modules(cds[genes_to_assess,], resolution=0.01)
# Out:
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’

# %%
cell_group_df <- tibble::tibble(cell=row.names(colData(cds)), 
                                cell_group= colData(cds)$cell_type)
agg_mat <- aggregate_gene_expression(cds, gene_module_df, cell_group_df)
row.names(agg_mat) <- stringr::str_c("Module ", row.names(agg_mat))
colnames(agg_mat) <- stringr::str_c(colnames(agg_mat))

pheatmap::pheatmap(agg_mat, cluster_rows=TRUE, cluster_cols=TRUE,
                   scale="column", clustering_method="ward.D2",
                   fontsize=6)
# Out:
# plot without title

# %%
options(warn = -1)

gene_module_dt <- as.data.table(gene_module_df)
target_genes_immune <- gene_module_dt[gene_module_df$module == c(8,9), id]
target_genes_lung_cells <- gene_module_dt[gene_module_df$module == 6, id]

options(warn = 1)

# %%
write.table(target_genes_immune, "/home/arsham79/scratch/nsclc/results/targeted_genes_monocole3_immune_cells.txt", 
            quote = FALSE, sep = "\t", eol = "\n", row.names = FALSE, col.names = FALSE)

write.table(target_genes_lung_cells, "/home/arsham79/scratch/nsclc/results/targeted_genes_monocole3_lung_cells.txt", 
            quote = FALSE, sep = "\t", eol = "\n", row.names = FALSE, col.names = FALSE)

# %%
sessionInfo()
# Out:
# R version 4.3.1 (2023-06-16)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: CentOS Linux 7 (Core)
#
# Matrix products: default
# BLAS/LAPACK: FlexiBLAS IMKL;  LAPACK version 3.9.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: America/New_York
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] lubridate_1.9.3             forcats_1.0.0
#  [3] stringr_1.5.1               dplyr_1.1.4
#  [5] purrr_1.0.2                 readr_2.1.4
#  [7] tidyr_1.3.0                 tibble_3.2.1
#  [9] tidyverse_2.0.0             ggplot2_3.4.4
# [11] monocle3_1.3.5              SingleCellExperiment_1.22.0
# [13] SummarizedExperiment_1.30.2 GenomicRanges_1.52.1
# [15] GenomeInfoDb_1.36.4         IRanges_2.34.1
# [17] S4Vectors_0.38.2            MatrixGenerics_1.12.3
# [19] matrixStats_1.2.0           Biobase_2.60.0
# [21] BiocGenerics_0.46.0         Seurat_5.0.1
# [23] SeuratObject_5.0.1          sp_2.1-2
# [25] data.table_1.14.10
#
# loaded via a namespace (and not attached):
#   [1] RColorBrewer_1.1-3        jsonlite_1.8.8
#   [3] magrittr_2.0.3            spatstat.utils_3.0-4
#   [5] nloptr_2.0.3              zlibbioc_1.46.0
#   [7] vctrs_0.6.5               ROCR_1.0-11
#   [9] Cairo_1.6-2               DelayedMatrixStats_1.22.6
#  [11] minqa_1.2.6               spatstat.explore_3.2-5
#  [13] RCurl_1.98-1.13           base64enc_0.1-3
#  [15] S4Arrays_1.2.1            htmltools_0.5.7
#  [17] sctransform_0.4.1         parallelly_1.36.0
#  [19] KernSmooth_2.23-21        htmlwidgets_1.6.4
#  [21] ica_1.0-3                 plyr_1.8.9
#  [23] plotly_4.10.3             zoo_1.8-12
#  [25] uuid_1.1-1                igraph_1.6.0
#  [27] mime_0.12                 lifecycle_1.0.4
#  [29] pkgconfig_2.0.3           Matrix_1.6-5
#  [31] R6_2.5.1                  fastmap_1.1.1
#  [33] GenomeInfoDbData_1.2.10   fitdistrplus_1.1-11
#  [35] future_1.33.1             shiny_1.8.0
#  [37] digest_0.6.33             colorspace_2.1-0
#  [39] patchwork_1.1.3           grr_0.9.5
#  [41] tensor_1.5                RSpectra_0.16-1
#  [43] irlba_2.3.5.1             progressr_0.14.0
#  [45] timechange_0.2.0          fansi_1.0.6
#  [47] spatstat.sparse_3.0-3     httr_1.4.7
#  [49] polyclip_1.10-6           abind_1.4-5
#  [51] compiler_4.3.1            withr_2.5.2
#  [53] fastDummies_1.7.3         MASS_7.3-60
#  [55] DelayedArray_0.26.7       tools_4.3.1
#  [57] lmtest_0.9-40             httpuv_1.6.13
#  [59] future.apply_1.11.1       goftest_1.2-3
#  [61] glue_1.6.2                nlme_3.1-162
#  [63] promises_1.2.1            grid_4.3.1
#  [65] pbdZMQ_0.3-10             Rtsne_0.17
#  [67] cluster_2.1.4             reshape2_1.4.4
#  [69] generics_0.1.3            gtable_0.3.4
#  [71] spatstat.data_3.0-3       tzdb_0.4.0
#  [73] hms_1.1.3                 XVector_0.40.0
#  [75] utf8_1.2.4                spatstat.geom_3.2-7
#  [77] RcppAnnoy_0.0.21          ggrepel_0.9.4
#  [79] RANN_2.6.1                pillar_1.9.0
#  [81] spam_2.10-0               IRdisplay_1.1
#  [83] RcppHNSW_0.5.0            later_1.3.2
#  [85] splines_4.3.1             lattice_0.21-8
#  [87] survival_3.5-5            deldir_2.0-2
#  [89] tidyselect_1.2.0          miniUI_0.1.1.1
#  [91] pbapply_1.7-2             gridExtra_2.3
#  [93] scattermore_1.2           pheatmap_1.0.12
#  [95] leidenbase_0.1.27         stringi_1.8.2
#  [97] boot_1.3-28.1             lazyeval_0.2.2
#  [99] evaluate_0.23             codetools_0.2-19
# [101] cli_3.6.2                 uwot_0.1.16
# [103] IRkernel_1.3.2.9000       xtable_1.8-4
# [105] reticulate_1.34.0         repr_1.1.6.9000
# [107] munsell_0.5.0             Rcpp_1.0.11
# [109] globals_0.16.2            spatstat.random_3.2-2
# [111] png_0.1-8                 parallel_4.3.1
# [113] ellipsis_0.3.2            assertthat_0.2.1
# [115] dotCall64_1.1-1           sparseMatrixStats_1.12.2
# [117] bitops_1.0-7              lme4_1.1-35.1
# [119] listenv_0.9.0             viridisLite_0.4.2
# [121] scales_1.3.0              ggridges_0.5.5
# [123] leiden_0.4.3.1            crayon_1.5.2
# [125] rlang_1.1.2               cowplot_1.1.2

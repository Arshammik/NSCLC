# %%
# Load libraries

suppressPackageStartupMessages(library(data.table))
suppressPackageStartupMessages(library(Seurat))
suppressPackageStartupMessages(library(monocle3))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(tidyverse))

set.seed(42)

# %%
# Files directory

monocole_3_learned_object_RDS_direction <- "/home/arsham79/projects/rrg-hsn/arsham79/nsclc//results/monocole3_cds_objectd_trained.rds"
monocole_3_DEGs_RDS_direction <- "/home/arsham79/projects/rrg-hsn/arsham79/nsclc//results/DEGs_monocole3.rds"
pbmc_Seurat_RDS_direction <- "/home/arsham79/projects/rrg-hsn/arsham79/nsclc/results/pbmc_cell_type_annotated.rds"

# %%
cds <- readRDS(monocole_3_learned_object_RDS_direction)

# %%
plot_cells(cds, color_cells_by = "partition", label_branch_points=FALSE, label_leaves=FALSE)
# Out:
# plot without title

# %%
plot_cells(cds, color_cells_by = "cell_type", label_groups_by_cluster=FALSE, label_leaves=FALSE, label_branch_points=FALSE, labels_per_group = FALSE)
# Out:
# plot without title

# %%
plot_cells(cds, color_cells_by = "pseudotime", label_groups_by_cluster=FALSE, label_leaves=FALSE, label_branch_points=TRUE)
# Out:
# Cells aren't colored in a way that allows them to be grouped.
# plot without title

# %%
cds$pseudotime_value <- pseudotime(cds)
pseudotime_df <- as.data.frame(colData(cds))

# %%
ggplot(pseudotime_df, aes(x = pseudotime_value, y = reorder(cell_type, pseudotime_value, median), fill = cell_type)) + geom_boxplot() + NoLegend()
# Out:
# plot without title

# %%
degs <- readRDS(monocole_3_DEGs_RDS_direction)
degs <- as.data.table(degs)

# %%
degs <- degs[degs$num_cell_expressed > 9601,]

# %%
degs <- degs[degs$morans_I > 0.100878,]

# %%
genes_to_assess <- degs$gene_short_name

# %%
cds <- preprocess_cds(cds)

# %%
gene_module_df_2 <- find_gene_modules(cds[genes_to_assess,], resolution=0.04)

# %%
cell_group_df <- tibble::tibble(cell=row.names(colData(cds)), 
                                cell_group= colData(cds)$cell_type)
agg_mat <- aggregate_gene_expression(cds, gene_module_df_2, cell_group_df)
row.names(agg_mat) <- stringr::str_c("Module ", row.names(agg_mat))
colnames(agg_mat) <- stringr::str_c(colnames(agg_mat))

pheatmap::pheatmap(agg_mat, cluster_rows=TRUE, cluster_cols=TRUE,
                   scale="column", clustering_method="ward.D2",
                   fontsize=6)
# Out:
# plot without title

# %%
# Converting to data table again

gene_module_dt <- as.data.table(gene_module_df_2)

# %%
module_cell_type_dt <- data.table(
    cell_types = c("Endothelial cells", "Fibroblasts", "AT type II", "Club cells", "AT type I", "AT type II like cells", "Ciliated cells",
    "Dendritic cells", "Monocytes", "B cells", "Plasma cells", "Mast cells", "NK cells", "T cells(CD8)", "T cells(CD4)"),
    module = paste0("Module_", c(4, 4, 12, 12, 11, 11, 11, 16, 8, 17, 17, 3, 19, 13, 13)))

# %%
# a uniqe string of the targeted modules
target_modules <- c(4, 12, 11, 16, 8, 17, 3, 19, 13)

# Specefing saving directory
save_module_dir <- "/home/arsham79/projects/rrg-hsn/arsham79/nsclc/results/modules/"

# for loop for all modules
for(i in 1:length(target_modules)){
    
    tmp_target <- target_modules[i]
    
    temp_module_dt <- gene_module_dt[gene_module_dt[, module == tmp_target,]]
    
    saveRDS(object = temp_module_dt ,file = paste0(save_module_dir, "Module_", tmp_target, ".rds"))
    

}

# %%
# Reading the Seurat object and modify the stage names

pbmc <- readRDS(pbmc_Seurat_RDS_direction)

# Creating the new names for visualizing in the right order
new_tumor_stage <- data.table(new_tumor_stage = c("1. Normal", "2. 0", "3. I", "4. II and III", "4. II and III", "5. IV"),
                              tumor_stage = c("N", "0", "I", "II", "III", "IV"))

old_tumor_stage <- data.table(tumor_stage = pbmc@meta.data$tumor_stage)
new_tumor_stage <- merge(old_tumor_stage, new_tumor_stage, by = "tumor_stage", sort = FALSE)
pbmc@meta.data$new_tumor_stage <- new_tumor_stage$new_tumor_stage

# Obtaining the normalized count

cnt <- GetAssayData(pbmc@assays$RNA_test)

# %%
#Creating custome metadata form Seurat object

meta <- data.table(cell.type = pbmc@active.ident,
                   cell_bar = names(pbmc@active.ident),
                   stage = pbmc@meta.data$new_tumor_stage)

# %%
# Creating a string for modules

new_tumor_stage = c("1. Normal", "2. 0", "3. I", "4. II and III", "4. II and III", "5. IV")

# %%
outer_list <- list()

for(m in 1:nrow(module_cell_type_dt)){
  
    temp_cell_type <- module_cell_type_dt[m,cell_types]
    temp_meta <- meta[meta$cell.type %in% temp_cell_type, ]
    temp_brc <- temp_meta[,cell_bar]
  
    temp_genes <- readRDS(paste0(save_module_dir, module_cell_type_dt[m,module], ".rds"))
    temp_genes <- temp_genes[,id]
  
    temp_cnt <- cnt[temp_genes,temp_brc]
  
    temp_dt_out <- data.table()
  
  for(i in 1:length(new_tumor_stage)){
  
        temp_stage <- new_tumor_stage[i]
        tem_trg_brc <- temp_meta[temp_meta$stage == temp_stage, cell_bar]
        temp_trg_cnt_rowsums <- Matrix::rowSums(temp_cnt[,tem_trg_brc])
    
        temp_dt <- data.table()
        temp_dt[, genes := rownames(temp_cnt)]
        temp_dt[, stage := temp_stage]
        temp_dt[, cell_type := temp_cell_type]
        temp_dt[, rowSums := temp_trg_cnt_rowsums]
    
        temp_dt_out <- rbind(temp_dt_out, temp_dt)
        #print(temp_stage) # ignoring to print the logs
    
  }
  
    name_of_loop <- paste0(module_cell_type_dt[m,module], "_", module_cell_type_dt[m,cell_types])
    outer_list[[name_of_loop]] <- temp_dt_out
    #print(name_of_loop) # ignoring to print the logs
}

# %%
cell_modules_sums <- rbindlist(outer_list)

# %%
unique(cell_modules_sums$cell_type)
# Out:
#  [1] "Endothelial cells"     "Fibroblasts"           "AT type II"
#  [4] "Club cells"            "AT type I"             "AT type II like cells"
#  [7] "Ciliated cells"        "Dendritic cells"       "Monocytes"
# [10] "B cells"               "Plasma cells"          "Mast cells"
# [13] "NK cells"              "T cells(CD8)"          "T cells(CD4)"

# %%
options(repr.plot.width = 7, repr.plot.height = 10)

ggplot(cell_modules_sums[cell_modules_sums$cell_type == "T cells(CD4)", ]) + 
        geom_bin2d(aes(x = stage, y = genes, fill = rowSums))
# Out:
# plot without title

# %%
options(repr.plot.width = 20, repr.plot.height = 35)
ggplot(cell_modules_sums[!(cell_modules_sums$cell_type == "T cells(CD4)"),]) +  # T cells(CD4) mess up the scale
        geom_bin2d(aes(x = stage, y = genes, fill = rowSums)) +
        facet_wrap(~cell_type, scales = "free") +
        scale_fill_viridis_c()
# Out:
# plot without title
